# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from imblearn.over_sampling import SMOTE
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Load dataset
train_data = pd.read_csv('Training_dt.csv')
train_data = train_data.drop('Mask No', axis=1)
test_data = pd.read_csv('Testing_dt.csv')
test_data = test_data.drop('Mask No', axis=1)

# Define columns
numerical_cols = ['LEASE_TENOR_INCLUDING_HP', 'CUSTOMER AGE', 'Exp','YOM' ]
categorical_cols = ['PRODUCT_NAME', 'Sub_purpose_code_based_on_risk', 'CRIB_SCORE', 'TOTAL INCOME',
                    'Percentage_of_Total_Installments_to_Total_Current_Balance_slabs',
                    'Percentage_of_Total_Current_Balance_to_Total_Amount_Granted_Limit_slabs',
                    'Percentage_of_Total_Arrears_Amount_to_Total_Amount_Granted_Limit_slabs']
target_col = 'Cluster'

# Preprocessing pipelines for numerical and categorical data
numerical_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# Preprocess the data
X_train = train_data.drop(columns=[target_col])
y_train = train_data[target_col]

X_test = test_data.drop(columns=[target_col])
y_test = test_data[target_col]

X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed = preprocessor.transform(X_test)

# Encode target variable
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Handle class imbalance using SMOTE
smote = SMOTE(random_state=64)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_processed, y_train_encoded)

# ANN model with additional hidden layers and tuned hyperparameters
model = Sequential()
model.add(Dense(39, input_dim=X_train_resampled.shape[1], activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(26, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(13, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(6, activation='sigmoid'))
model.add(Dropout(0.2))
#model.add(Dense(3, activation='softmax'))
#model.add(Dropout(0.2))
#model.add(Dense(25, activation='relu'))
#model.add(Dense(len(np.unique(y_train_resampled)), activation='softmax'))
model.add(Dense(2, activation='sigmoid'))

# Compile the model with a lower learning rate and additional epochs
model.compile(optimizer=Adam(learning_rate=0.0005), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Early stopping to avoid overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# Train the model with more epochs
model.fit(X_train_resampled, y_train_resampled, validation_split=0.2, epochs=400, batch_size=64, callbacks=[early_stopping])

# Evaluate the model
loss, accuracy = model.evaluate(X_test_processed, y_test_encoded)
print(f'Test Accuracy: {accuracy}')

# Make predictions
y_pred = model.predict(X_test_processed)
y_pred_labels = np.argmax(y_pred, axis=1)

# Decode predictions back to original labels
y_pred_labels_decoded = label_encoder.inverse_transform(y_pred_labels)

# Generate confusion matrix
cm = confusion_matrix(y_test_encoded, y_pred_labels)
print('Confusion Matrix:')
print(cm)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Generate classification report
report = classification_report(y_test_encoded, y_pred_labels, target_names=label_encoder.classes_)
print('Classification Report:')
print(report)

# Save predictions to a new file
test_data['Predicted_Cluster'] = y_pred_labels_decoded
test_data.to_csv('Testing_dt_with_Predictions.csv', index=False)


# Save the model and other necessary files
model.save('best_ann_model_v2.h5')
#joblib.dump(ml, 'best_ml_model_v2.pkl')
joblib.dump(preprocessor, 'preprocessor_v2.pkl')
joblib.dump(label_encoder, 'label_encoder_v2.pkl')
# Out:
# Epoch 1/400
# C:\Users\User\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6063 - loss: 0.7190 - val_accuracy: 0.0000e+00 - val_loss: 0.9706
# Epoch 2/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.5776 - loss: 0.6921 - val_accuracy: 0.0000e+00 - val_loss: 0.9361
# Epoch 3/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.5925 - loss: 0.6769 - val_accuracy: 0.0000e+00 - val_loss: 0.9558
# Epoch 4/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.6084 - loss: 0.6707 - val_accuracy: 0.0000e+00 - val_loss: 0.9487
# Epoch 5/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.6062 - loss: 0.6699 - val_accuracy: 0.0000e+00 - val_loss: 0.9469
# Epoch 6/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.6148 - loss: 0.6632 - val_accuracy: 0.0000e+00 - val_loss: 0.9489
# Epoch 7/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 0.6099 - loss: 0.6588 - val_accuracy: 0.0000e+00 - val_loss: 0.9479
# Epoch 8/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.6272 - loss: 0.6432 - val_accuracy: 0.0000e+00 - val_loss: 0.9099
# Epoch 9/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 0.6351 - loss: 0.6318 - val_accuracy: 0.0137 - val_loss: 0.9082
# Epoch 10/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - accuracy: 0.6440 - loss: 0.6254 - val_accuracy: 0.4311 - val_loss: 0.8763
# Epoch 11/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.6517 - loss: 0.6240 - val_accuracy: 0.4898 - val_loss: 0.8724
# Epoch 12/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - accuracy: 0.6427 - loss: 0.6308 - val_accuracy: 0.4775 - val_loss: 0.9037
# Epoch 13/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - accuracy: 0.6630 - loss: 0.6159 - val_accuracy: 0.5419 - val_loss: 0.8584
# Epoch 14/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - accuracy: 0.6614 - loss: 0.6153 - val_accuracy: 0.5317 - val_loss: 0.8709
# Epoch 15/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - accuracy: 0.6689 - loss: 0.6130 - val_accuracy: 0.5454 - val_loss: 0.8605
# Epoch 16/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.6667 - loss: 0.6074 - val_accuracy: 0.5568 - val_loss: 0.8583
# Epoch 17/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 0.6705 - loss: 0.6059 - val_accuracy: 0.5362 - val_loss: 0.8863
# Epoch 18/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.6743 - loss: 0.6069 - val_accuracy: 0.5489 - val_loss: 0.8695
# Epoch 19/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.6741 - loss: 0.6092 - val_accuracy: 0.5381 - val_loss: 0.8765
# Epoch 20/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.6705 - loss: 0.6159 - val_accuracy: 0.5327 - val_loss: 0.8792
# Epoch 21/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.6693 - loss: 0.6097 - val_accuracy: 0.5352 - val_loss: 0.8779
# Epoch 22/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.6787 - loss: 0.6079 - val_accuracy: 0.5381 - val_loss: 0.8754
# Epoch 23/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.6841 - loss: 0.6006 - val_accuracy: 0.5403 - val_loss: 0.8653
# Epoch 24/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.6850 - loss: 0.6062 - val_accuracy: 0.5543 - val_loss: 0.8491
# Epoch 25/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.6755 - loss: 0.6087 - val_accuracy: 0.5454 - val_loss: 0.8608
# Epoch 26/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.6842 - loss: 0.6075 - val_accuracy: 0.5390 - val_loss: 0.8734
# Epoch 27/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.6803 - loss: 0.6091 - val_accuracy: 0.5270 - val_loss: 0.8827
# Epoch 28/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.6803 - loss: 0.6040 - val_accuracy: 0.5276 - val_loss: 0.8803
# Epoch 29/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.6848 - loss: 0.5967 - val_accuracy: 0.5333 - val_loss: 0.8727
# Epoch 30/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.6900 - loss: 0.6026 - val_accuracy: 0.5241 - val_loss: 0.8788
# Epoch 31/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.6789 - loss: 0.6051 - val_accuracy: 0.5378 - val_loss: 0.8617
# Epoch 32/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.6785 - loss: 0.6045 - val_accuracy: 0.5260 - val_loss: 0.8746
# Epoch 33/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.6745 - loss: 0.6095 - val_accuracy: 0.5337 - val_loss: 0.8746
# Epoch 34/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.6846 - loss: 0.5990 - val_accuracy: 0.5390 - val_loss: 0.8588
# Epoch 35/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 0.6834 - loss: 0.6038 - val_accuracy: 0.5263 - val_loss: 0.8722
# Epoch 36/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.6837 - loss: 0.6018 - val_accuracy: 0.5276 - val_loss: 0.8666
# Epoch 37/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 0.6818 - loss: 0.6026 - val_accuracy: 0.5197 - val_loss: 0.8768
# Epoch 38/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.6833 - loss: 0.6013 - val_accuracy: 0.5219 - val_loss: 0.8716
# Epoch 39/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.6820 - loss: 0.6018 - val_accuracy: 0.5175 - val_loss: 0.8754
# Epoch 40/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.6802 - loss: 0.6043 - val_accuracy: 0.5276 - val_loss: 0.8570
# Epoch 41/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.6870 - loss: 0.6060 - val_accuracy: 0.5302 - val_loss: 0.8604
# Epoch 42/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.6911 - loss: 0.5934 - val_accuracy: 0.5171 - val_loss: 0.8798
# Epoch 43/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.6834 - loss: 0.6015 - val_accuracy: 0.5165 - val_loss: 0.8659
# Epoch 44/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.6806 - loss: 0.6014 - val_accuracy: 0.5289 - val_loss: 0.8543
# Epoch 45/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.6852 - loss: 0.6025 - val_accuracy: 0.5095 - val_loss: 0.8920
# Epoch 46/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.6989 - loss: 0.5894 - val_accuracy: 0.5244 - val_loss: 0.8557
# Epoch 47/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.6951 - loss: 0.5930 - val_accuracy: 0.5254 - val_loss: 0.8482
# Epoch 48/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - accuracy: 0.6912 - loss: 0.5937 - val_accuracy: 0.5276 - val_loss: 0.8479
# Epoch 49/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.6910 - loss: 0.5940 - val_accuracy: 0.5143 - val_loss: 0.8586
# Epoch 50/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - accuracy: 0.6908 - loss: 0.5944 - val_accuracy: 0.5181 - val_loss: 0.8589
# Epoch 51/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.6863 - loss: 0.5950 - val_accuracy: 0.5102 - val_loss: 0.8678
# Epoch 52/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.6883 - loss: 0.5992 - val_accuracy: 0.5086 - val_loss: 0.8620
# Epoch 53/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.6920 - loss: 0.5958 - val_accuracy: 0.5124 - val_loss: 0.8539
# Epoch 54/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.6866 - loss: 0.5953 - val_accuracy: 0.5130 - val_loss: 0.8633
# Epoch 55/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - accuracy: 0.6866 - loss: 0.6003 - val_accuracy: 0.4889 - val_loss: 0.8897
# Epoch 56/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.6897 - loss: 0.5938 - val_accuracy: 0.4990 - val_loss: 0.8838
# Epoch 57/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 0.6924 - loss: 0.6003 - val_accuracy: 0.5086 - val_loss: 0.8569
# Epoch 58/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.6868 - loss: 0.5984 - val_accuracy: 0.4886 - val_loss: 0.8772
# Epoch 59/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.6938 - loss: 0.5962 - val_accuracy: 0.4924 - val_loss: 0.8707
# Epoch 60/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.6931 - loss: 0.5938 - val_accuracy: 0.4968 - val_loss: 0.8638
# Epoch 61/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 0.6871 - loss: 0.5996 - val_accuracy: 0.4994 - val_loss: 0.8586
# Epoch 62/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - accuracy: 0.6926 - loss: 0.5936 - val_accuracy: 0.5006 - val_loss: 0.8593
# Epoch 63/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.6918 - loss: 0.5930 - val_accuracy: 0.5025 - val_loss: 0.8581
# Epoch 64/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.6920 - loss: 0.5952 - val_accuracy: 0.5016 - val_loss: 0.8521
# Epoch 65/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.6862 - loss: 0.5947 - val_accuracy: 0.5013 - val_loss: 0.8618
# Epoch 66/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 0.6919 - loss: 0.5923 - val_accuracy: 0.4848 - val_loss: 0.8752
# Epoch 67/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 0.6904 - loss: 0.5955 - val_accuracy: 0.5006 - val_loss: 0.8543
# Epoch 68/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.6938 - loss: 0.5940 - val_accuracy: 0.4975 - val_loss: 0.8591
# Epoch 69/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.6910 - loss: 0.5933 - val_accuracy: 0.4825 - val_loss: 0.8675
# Epoch 70/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.6923 - loss: 0.5933 - val_accuracy: 0.5035 - val_loss: 0.8406
# Epoch 71/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.6926 - loss: 0.5898 - val_accuracy: 0.4968 - val_loss: 0.8495
# Epoch 72/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.6905 - loss: 0.5939 - val_accuracy: 0.4930 - val_loss: 0.8475
# Epoch 73/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 0.6935 - loss: 0.5921 - val_accuracy: 0.4768 - val_loss: 0.8754
# Epoch 74/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.6984 - loss: 0.5907 - val_accuracy: 0.5032 - val_loss: 0.8444
# Epoch 75/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.6933 - loss: 0.5905 - val_accuracy: 0.4813 - val_loss: 0.8634
# Epoch 76/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.6950 - loss: 0.5931 - val_accuracy: 0.4883 - val_loss: 0.8506
# Epoch 77/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.6881 - loss: 0.5917 - val_accuracy: 0.4968 - val_loss: 0.8451
# Epoch 78/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 0.6874 - loss: 0.5964 - val_accuracy: 0.4800 - val_loss: 0.8602
# Epoch 79/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.6901 - loss: 0.5986 - val_accuracy: 0.5041 - val_loss: 0.8325
# Epoch 80/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 0.6845 - loss: 0.5992 - val_accuracy: 0.4892 - val_loss: 0.8526
# Epoch 81/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.6800 - loss: 0.5992 - val_accuracy: 0.4886 - val_loss: 0.8574
# Epoch 82/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.6910 - loss: 0.5925 - val_accuracy: 0.4803 - val_loss: 0.8580
# Epoch 83/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.6866 - loss: 0.5974 - val_accuracy: 0.4638 - val_loss: 0.8753
# Epoch 84/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - accuracy: 0.6833 - loss: 0.5974 - val_accuracy: 0.4797 - val_loss: 0.8494
# Epoch 85/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.6939 - loss: 0.5908 - val_accuracy: 0.4673 - val_loss: 0.8577
# Epoch 86/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.6940 - loss: 0.5883 - val_accuracy: 0.4790 - val_loss: 0.8421
# Epoch 87/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.6912 - loss: 0.5914 - val_accuracy: 0.4711 - val_loss: 0.8688
# Epoch 88/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.6938 - loss: 0.5905 - val_accuracy: 0.4679 - val_loss: 0.8639
# Epoch 89/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 0.6900 - loss: 0.5935 - val_accuracy: 0.4521 - val_loss: 0.8693
# Epoch 90/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - accuracy: 0.6900 - loss: 0.5919 - val_accuracy: 0.4724 - val_loss: 0.8543
# Epoch 91/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - accuracy: 0.6821 - loss: 0.5943 - val_accuracy: 0.4610 - val_loss: 0.8544
# Epoch 92/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.6899 - loss: 0.5898 - val_accuracy: 0.4654 - val_loss: 0.8552
# Epoch 93/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 0.6814 - loss: 0.5942 - val_accuracy: 0.4771 - val_loss: 0.8385
# Epoch 94/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.6930 - loss: 0.5887 - val_accuracy: 0.4835 - val_loss: 0.8445
# Epoch 95/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.6903 - loss: 0.5908 - val_accuracy: 0.4711 - val_loss: 0.8617
# Epoch 96/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - accuracy: 0.6890 - loss: 0.5944 - val_accuracy: 0.4673 - val_loss: 0.8588
# Epoch 97/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.6967 - loss: 0.5859 - val_accuracy: 0.4714 - val_loss: 0.8533
# Epoch 98/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - accuracy: 0.6969 - loss: 0.5869 - val_accuracy: 0.4746 - val_loss: 0.8409
# Epoch 99/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.6833 - loss: 0.5992 - val_accuracy: 0.4743 - val_loss: 0.8548
# Epoch 100/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.6898 - loss: 0.5896 - val_accuracy: 0.4825 - val_loss: 0.8424
# Epoch 101/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - accuracy: 0.6941 - loss: 0.5819 - val_accuracy: 0.4746 - val_loss: 0.8515
# Epoch 102/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.6950 - loss: 0.5926 - val_accuracy: 0.4730 - val_loss: 0.8522
# Epoch 103/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.6887 - loss: 0.5951 - val_accuracy: 0.4803 - val_loss: 0.8399
# Epoch 104/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 0.6942 - loss: 0.5888 - val_accuracy: 0.4733 - val_loss: 0.8414
# Epoch 105/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.6942 - loss: 0.5876 - val_accuracy: 0.4746 - val_loss: 0.8292
# Epoch 106/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - accuracy: 0.6918 - loss: 0.5929 - val_accuracy: 0.4644 - val_loss: 0.8506
# Epoch 107/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.6956 - loss: 0.5848 - val_accuracy: 0.4819 - val_loss: 0.8345
# Epoch 108/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.6888 - loss: 0.5908 - val_accuracy: 0.4648 - val_loss: 0.8604
# Epoch 109/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.6984 - loss: 0.5832 - val_accuracy: 0.4679 - val_loss: 0.8493
# Epoch 110/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6911 - loss: 0.5876 - val_accuracy: 0.4594 - val_loss: 0.8614
# Epoch 111/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.6959 - loss: 0.5913 - val_accuracy: 0.4727 - val_loss: 0.8433
# Epoch 112/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - accuracy: 0.6978 - loss: 0.5821 - val_accuracy: 0.4629 - val_loss: 0.8529
# Epoch 113/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.6880 - loss: 0.5908 - val_accuracy: 0.4705 - val_loss: 0.8506
# Epoch 114/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.6938 - loss: 0.5848 - val_accuracy: 0.4733 - val_loss: 0.8459
# Epoch 115/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.6987 - loss: 0.5841 - val_accuracy: 0.4860 - val_loss: 0.8304
# Epoch 116/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - accuracy: 0.6927 - loss: 0.5886 - val_accuracy: 0.4657 - val_loss: 0.8498
# Epoch 117/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.6922 - loss: 0.5866 - val_accuracy: 0.4629 - val_loss: 0.8498
# Epoch 118/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.6949 - loss: 0.5879 - val_accuracy: 0.4686 - val_loss: 0.8454
# Epoch 119/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.6977 - loss: 0.5812 - val_accuracy: 0.4708 - val_loss: 0.8424
# Epoch 120/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.6983 - loss: 0.5799 - val_accuracy: 0.4730 - val_loss: 0.8424
# Epoch 121/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - accuracy: 0.6929 - loss: 0.5868 - val_accuracy: 0.4683 - val_loss: 0.8439
# Epoch 122/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.6965 - loss: 0.5876 - val_accuracy: 0.4527 - val_loss: 0.8568
# Epoch 123/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.7011 - loss: 0.5833 - val_accuracy: 0.4594 - val_loss: 0.8456
# Epoch 124/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.6966 - loss: 0.5868 - val_accuracy: 0.4546 - val_loss: 0.8517
# Epoch 125/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.6914 - loss: 0.5872 - val_accuracy: 0.4667 - val_loss: 0.8444
# Epoch 126/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.6963 - loss: 0.5870 - val_accuracy: 0.4622 - val_loss: 0.8506
# Epoch 127/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - accuracy: 0.6988 - loss: 0.5829 - val_accuracy: 0.4727 - val_loss: 0.8345
# Epoch 128/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 0.6823 - loss: 0.5972 - val_accuracy: 0.4422 - val_loss: 0.8726
# Epoch 129/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - accuracy: 0.6937 - loss: 0.5867 - val_accuracy: 0.4514 - val_loss: 0.8694
# Epoch 130/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.6828 - loss: 0.5941 - val_accuracy: 0.4483 - val_loss: 0.8617
# Epoch 131/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.6940 - loss: 0.5847 - val_accuracy: 0.4708 - val_loss: 0.8394
# Epoch 132/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - accuracy: 0.6972 - loss: 0.5855 - val_accuracy: 0.4711 - val_loss: 0.8436
# Epoch 133/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - accuracy: 0.6976 - loss: 0.5844 - val_accuracy: 0.4578 - val_loss: 0.8574
# Epoch 134/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.7016 - loss: 0.5823 - val_accuracy: 0.4654 - val_loss: 0.8406
# Epoch 135/400
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - accuracy: 0.6895 - loss: 0.5906 - val_accuracy: 0.4584 - val_loss: 0.8530
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - accuracy: 0.7223 - loss: 0.5602
# Test Accuracy: 0.7015066146850586
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Confusion Matrix:
# [[507 162]
#  [155 238]]
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Classification Report:
#               precision    recall  f1-score   support
#
#        Green       0.77      0.76      0.76       669
#          Red       0.59      0.61      0.60       393
#
#     accuracy                           0.70      1062
#    macro avg       0.68      0.68      0.68      1062
# weighted avg       0.70      0.70      0.70      1062
# ['label_encoder_v2.pkl']

# %%
import pandas as pd
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf

# Load the test dataset
test_data_1242 = pd.read_csv('My_Test_data.csv')
#test_data_1242 = test_data_1242.drop('Mask No', axis=1)

# Define columns
numerical_cols = ['LEASE_TENOR_INCLUDING_HP', 'CUSTOMER AGE', 'Exp', 'YOM']
categorical_cols = ['PRODUCT_NAME', 'Sub_purpose_code_based_on_risk', 'CRIB_SCORE', 'TOTAL INCOME',
                    'Percentage_of_Total_Installments_to_Total_Current_Balance_slabs',
                    'Percentage_of_Total_Current_Balance_to_Total_Amount_Granted_Limit_slabs',
                    'Percentage_of_Total_Arrears_Amount_to_Total_Amount_Granted_Limit_slabs']
target_col = 'Cluster'

# Load the pre-trained models and encoders
model = tf.keras.models.load_model('best_ann_model_v2.h5')
preprocessor = joblib.load('preprocessor_v2.pkl')
label_encoder = joblib.load('label_encoder_v2.pkl')

# Preprocess the data
X_test_1242 = test_data_1242.drop(columns=[target_col])
y_test_1242 = test_data_1242[target_col]

X_test_1242_processed = preprocessor.transform(X_test_1242)
y_test_1242_encoded = label_encoder.transform(y_test_1242)

# Make predictions
y_pred_1242 = model.predict(X_test_1242_processed)
y_pred_1242_labels = np.argmax(y_pred_1242, axis=1)

# Decode predictions back to original labels
y_pred_1242_labels_decoded = label_encoder.inverse_transform(y_pred_1242_labels)

# Generate confusion matrix
cm_1242 = confusion_matrix(y_test_1242_encoded, y_pred_1242_labels)
print('Confusion Matrix:')
print(cm_1242)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm_1242, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for test1242.csv')
plt.show()

# Generate classification report
report_1242 = classification_report(y_test_1242_encoded, y_pred_1242_labels, target_names=label_encoder.classes_)
print('Classification Report:')
print(report_1242)

# Save predictions to a new file
test_data_1242['Predicted_Cluster'] = y_pred_1242_labels_decoded
test_data_1242.to_excel('test1242_with_Predictions.xlsx', index=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Confusion Matrix:
# [[661 220]
#  [147 214]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        Green       0.82      0.75      0.78       881
#          Red       0.49      0.59      0.54       361
#
#     accuracy                           0.70      1242
#    macro avg       0.66      0.67      0.66      1242
# weighted avg       0.72      0.70      0.71      1242
